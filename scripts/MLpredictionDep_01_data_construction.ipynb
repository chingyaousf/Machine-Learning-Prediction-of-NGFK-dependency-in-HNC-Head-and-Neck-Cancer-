# %% [markdown]
# <a href="https://colab.research.google.com/github/chingyaousf/Machine-Learning-Prediction-of-NGFK-dependency-in-HNC-Head-and-Neck-Cancer-/blob/main/scripts/MLpredictionDep_01_data_construction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Read the CSV file
arranged_table = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/arranged_table.csv")

# Transpose the DataFrame
arranged_table_transposed = arranged_table.transpose()

# Reset the index and set new column names
arranged_table_transposed = arranged_table_transposed.reset_index()
arranged_table_transposed.columns = arranged_table_transposed.iloc[0]
arranged_table_transposed = arranged_table_transposed.iloc[1:]

# Adjust the leftmost column to count from 0
arranged_table_transposed.reset_index(drop=True, inplace=True)

# Save the transposed DataFrame to a CSV file
arranged_table_transposed.to_csv("/content/drive/MyDrive/Colab Notebooks/DeepDEP/arranged_table_transposed.csv", index=False)

arranged_table_transposed
# Out:
# 0      DepMap_ID A1BG (1) Dep A1BG (1) Exp A1CF (29974) Dep A1CF (29974) Exp  \
# 0     ACH-000001     0.094568     3.116032         0.012519         0.056584
# 1     ACH-000004     0.012676     4.178715         0.049011              0.0
# 2     ACH-000005     0.053957     4.003602         0.027968         0.014355
# 3     ACH-000007     0.026704     0.137504         0.083588         1.405992
# 4     ACH-000009     0.059383     1.464668         0.051826         3.586164
# ...          ...          ...          ...              ...              ...
# 1000  ACH-002785     0.063758     1.967169         0.039244              0.0
# 1001  ACH-002800     0.030591     3.847997         0.040334              0.0
# 1002  ACH-002834      0.01272     1.819668          0.08384         0.014355
# 1003  ACH-002847     0.058547     2.990955         0.079576              0.0
# 1004  ACH-002926      0.02201     3.189034         0.023496              0.0
#
# ...

# %%
import pandas as pd

# Read the CSV file
arranged_table = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/DeepDEP/arranged_table_transposed.csv")

# Separate the column names with "Exp" and "Dep"
exp_columns = [col for col in arranged_table.columns if col.endswith(" Exp")]
dep_columns = [col for col in arranged_table.columns if col.endswith(" Dep")]

# Reorder the columns with "Exp" on the left and "Dep" on the right
new_columns = ["DepMap_ID"] + exp_columns + dep_columns

# Create a new DataFrame with the reordered columns
arranged_table_reordered = arranged_table[new_columns]

# Adjust the leftmost column to count from 0
arranged_table_reordered.reset_index(drop=True, inplace=True)

arranged_table_reordered
# Out:
#        DepMap_ID  A1BG (1) Exp  A1CF (29974) Exp  A2M (2) Exp  \
# 0     ACH-000001      3.116032          0.056584     0.226509
# 1     ACH-000004      4.178715          0.000000     0.214125
# 2     ACH-000005      4.003602          0.014355     0.137504
# 3     ACH-000007      0.137504          1.405992     0.201634
# 4     ACH-000009      1.464668          3.586164     0.250962
# ...          ...           ...               ...          ...
# 1000  ACH-002785      1.967169          0.000000     2.198494
# 1001  ACH-002800      3.847997          0.000000     5.899901
# 1002  ACH-002834      1.819668          0.014355     0.014355
# 1003  ACH-002847      2.990955          0.000000     7.608440
# 1004  ACH-002926      3.189034          0.000000     9.335390
#
#       A2ML1 (144568) Exp  A3GALT2 (127550) Exp  A4GALT (53947) Exp  \
# 0               0.111031              0.000000            1.035624
# 1               0.344828              0.070389            0.097611
# ...

# %%
# Find the column names containing the specified strings
target_columns = arranged_table_reordered.columns[arranged_table_reordered.columns.str.contains('EIF2AK3|SF3B1|NQO1|SQSTM1|MYC|HSP70')]

target_columns
# Out:
# Index(['EIF2AK3 (9451) Exp', 'MYC (4609) Exp', 'MYCBP (26292) Exp',
#        'MYCBPAP (84073) Exp', 'MYCL (4610) Exp', 'MYCN (4613) Exp',
#        'MYCT1 (80177) Exp', 'NQO1 (1728) Exp', 'SF3B1 (23451) Exp',
#        'SQSTM1 (8878) Exp', 'EIF2AK3 (9451) Dep', 'MYC (4609) Dep',
#        'MYCBP (26292) Dep', 'MYCBPAP (84073) Dep', 'MYCL (4610) Dep',
#        'MYCN (4613) Dep', 'MYCT1 (80177) Dep', 'NQO1 (1728) Dep',
#        'SF3B1 (23451) Dep', 'SQSTM1 (8878) Dep'],
#       dtype='object')

# %%
# Find the column names exactly matching the specified strings
target_columns = arranged_table_reordered.columns[arranged_table_reordered.columns.str.match('EIF2AK3 |SF3B1 |NQO1 |SQSTM1 |MYC |HSP70 ')]

target_columns
# Out:
# Index(['EIF2AK3 (9451) Exp', 'MYC (4609) Exp', 'NQO1 (1728) Exp',
#        'SF3B1 (23451) Exp', 'SQSTM1 (8878) Exp', 'EIF2AK3 (9451) Dep',
#        'MYC (4609) Dep', 'NQO1 (1728) Dep', 'SF3B1 (23451) Dep',
#        'SQSTM1 (8878) Dep'],
#       dtype='object')

# %%
# Create a list of column names to preserve

preserved_columns = ["EIF2AK3", "SF3B1", "NQO1", "SQSTM1", "MYC", "HSP70"]

# Filter the columns based on the preserved column names
filtered_columns = [col for col in arranged_table_reordered.columns if (col.endswith(" Dep") and col.split(" ")[0] in preserved_columns) or not col.endswith(" Dep")]

# Create a new DataFrame with the filtered columns
filtered_arranged_table = arranged_table_reordered[filtered_columns]

# Save the filtered_arranged_table DataFrame to a CSV file
filtered_arranged_table.to_csv("/content/drive/MyDrive/Colab Notebooks/DeepDEP/filtered_arranged_table.csv", index=False)

filtered_arranged_table
# Out:
#        DepMap_ID  A1BG (1) Exp  A1CF (29974) Exp  A2M (2) Exp  \
# 0     ACH-000001      3.116032          0.056584     0.226509
# 1     ACH-000004      4.178715          0.000000     0.214125
# 2     ACH-000005      4.003602          0.014355     0.137504
# 3     ACH-000007      0.137504          1.405992     0.201634
# 4     ACH-000009      1.464668          3.586164     0.250962
# ...          ...           ...               ...          ...
# 1000  ACH-002785      1.967169          0.000000     2.198494
# 1001  ACH-002800      3.847997          0.000000     5.899901
# 1002  ACH-002834      1.819668          0.014355     0.014355
# 1003  ACH-002847      2.990955          0.000000     7.608440
# 1004  ACH-002926      3.189034          0.000000     9.335390
#
#       A2ML1 (144568) Exp  A3GALT2 (127550) Exp  A4GALT (53947) Exp  \
# 0               0.111031              0.000000            1.035624
# 1               0.344828              0.070389            0.097611
# ...

# %%
# Create filtered_arranged_hnc_table.csv
# Create a list of column names to preserve

preserved_columns = ['AKT1', 'EGFR', 'NOTCH3', 'AKT3', 'NOTCH2', 'MAPK3', 'MET', 'AKT2', 'MAPK1', 'NOTCH1']

# Filter the columns based on the preserved column names
filtered_columns = [col for col in arranged_table_reordered.columns if (col.endswith(" Dep") and col.split(" ")[0] in preserved_columns) or not col.endswith(" Dep")]

# Create a new DataFrame with the filtered columns
filtered_arranged_hnc_table = arranged_table_reordered[filtered_columns]

# Save the filtered_arranged_table DataFrame to a CSV file
filtered_arranged_hnc_table.to_csv("/content/drive/MyDrive/Colab Notebooks/features engineering/filtered_arranged_hnc_table.csv", index=False)

filtered_arranged_hnc_table
# Out:
#        DepMap_ID  A1BG (1) Exp  A1CF (29974) Exp  A2M (2) Exp  \
# 0     ACH-000001      3.116032          0.056584     0.226509
# 1     ACH-000004      4.178715          0.000000     0.214125
# 2     ACH-000005      4.003602          0.014355     0.137504
# 3     ACH-000007      0.137504          1.405992     0.201634
# 4     ACH-000009      1.464668          3.586164     0.250962
# ...          ...           ...               ...          ...
# 1000  ACH-002785      1.967169          0.000000     2.198494
# 1001  ACH-002800      3.847997          0.000000     5.899901
# 1002  ACH-002834      1.819668          0.014355     0.014355
# 1003  ACH-002847      2.990955          0.000000     7.608440
# 1004  ACH-002926      3.189034          0.000000     9.335390
#
#       A2ML1 (144568) Exp  A3GALT2 (127550) Exp  A4GALT (53947) Exp  \
# 0               0.111031              0.000000            1.035624
# 1               0.344828              0.070389            0.097611
# ...

# %%
# Display Oral_Squamous_Cell_Carcinoma CCL (Cancer Cell Line)

import pandas as pd

# Read the CSV file
Oral_Squamous_Cell_Carcinoma = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Oral_Squamous_Cell_Carcinoma/Oral_Squamous_Cell_Carcinoma.csv")

Oral_Squamous_Cell_Carcinoma
# Out:
#        ModelID  PatientID            CellLineName StrippedCellLineName  \
# 0   ACH-000181  PT-UbMDmb                   SCC-9                 SCC9
# 1   ACH-000188  PT-Iz4kXj                  SCC-25                SCC25
# 2   ACH-000228  PT-HX0QLG                 BICR 31               BICR31
# 3   ACH-000238  PT-Kf5TA3                   SCC-4                 SCC4
# 4   ACH-000254  PT-nowpOK                  SCC-15                SCC15
# 5   ACH-000472  PT-MxVfNi                   HSC-2                 HSC2
# 6   ACH-000503  PT-9uZV0s                 BICR 16               BICR16
# 7   ACH-000518  PT-czsVU5                  CAL-33                CAL33
# 8   ACH-000546  PT-F3GXIi                   HSC-4                 HSC4
# 9   ACH-000548  PT-p0K5QM                     BHY                  BHY
# 10  ACH-000606  PT-qno39F  PE/CA-PJ34 (clone C12)     PECAPJ34CLONEC12
# 11  ACH-000619  PT-UF0NQM              PE/CA-PJ15             PECAPJ15
# ...

# %%
# Extract filtered_arranged_table.cs matching with Oral_Squamous_Cell_Carcinoma CCL (Cancer Cell Line) to have filtered_arranged_table_Oral_Squamous.csv

import pandas as pd

# Read file 1
file1_path = '/content/drive/MyDrive/Colab Notebooks/DeepDEP/filtered_arranged_table.csv'
file1_df = pd.read_csv(file1_path)

# Read file 2
file2_path = '/content/drive/MyDrive/Colab Notebooks/Oral_Squamous_Cell_Carcinoma/Oral_Squamous_Cell_Carcinoma.csv'
file2_df = pd.read_csv(file2_path)

# Get the matching rows from file 1
filtered_arranged_table_Oral_Squamous = file1_df[file1_df['DepMap_ID'].isin(file2_df['ModelID'])]

# Save the filtered_arranged_table_Oral_Squamou DataFrame to a CSV file
filtered_arranged_table_Oral_Squamous.to_csv("/content/drive/MyDrive/Colab Notebooks/Oral_Squamous_Cell_Carcinoma/filtered_arranged_table_Oral_Squamous.csv", index=False)

# Display filtered_arranged_table_Oral_Squamous
filtered_arranged_table_Oral_Squamous
# Out:
#       DepMap_ID  A1BG (1) Exp  A1CF (29974) Exp  A2M (2) Exp  \
# 99   ACH-000181      4.238023          0.056584     0.111031
# 103  ACH-000188      2.432959          0.014355     0.189034
# 128  ACH-000228      5.128871          0.014355     0.150560
# 135  ACH-000238      3.117695          0.070389     0.163499
# 296  ACH-000472      0.555816          0.028569     0.189034
# 321  ACH-000503      2.809414          0.028569     0.124328
# 331  ACH-000518      0.632268          0.014355     0.042644
# 347  ACH-000546      0.475085          0.042644     0.150560
# 349  ACH-000548      2.859970          0.014355     0.422233
# 390  ACH-000606      0.333424          0.000000     0.201634
# 397  ACH-000619      0.000000          0.000000     0.214125
# 404  ACH-000630      1.090853          0.014355     1.851999
# 468  ACH-000732      2.568032          0.000000     0.298658
# 470  ACH-000735      0.189034          0.014355     0.150560
# ...

# %%
import pandas as pd

# Read file 1
file1_path = '/content/drive/MyDrive/Colab Notebooks/DeepDEP/filtered_arranged_table.csv'
file1_df = pd.read_csv(file1_path)

# Read file 2
file2_path = '/content/drive/MyDrive/Colab Notebooks/Oral_Squamous_Cell_Carcinoma/Oral Cavity Squamous Cell Carcinoma.csv'
file2_df = pd.read_csv(file2_path)

# Merge the data frames based on the first column (DepMap_ID and ModelID)
merged_df = pd.merge(file1_df, file2_df, left_on='DepMap_ID', right_on='ModelID')

# Save the merged data to a new CSV file
output_path = '/content/drive/MyDrive/Colab Notebooks/merged_data.csv'
merged_df.to_csv(output_path, index=False)

# %%
# checking some columns values

import pandas as pd

# Load the CSV file into a DataFrame
filtered_arranged_table = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/DeepDEP/filtered_arranged_table.csv")

# Select the desired columns
selected_columns = filtered_arranged_table[["AAK1 (22848) Exp","ABCA4 (24) Exp","ACER3 (55331) Exp"]]

# Display the selected columns
selected_columns
# Out:
#       AAK1 (22848) Exp  ABCA4 (24) Exp  ACER3 (55331) Exp
# 0             3.078951        2.443607           5.980025
# 1             2.292782        0.713696           3.648465
# 2             2.625270        0.163499           4.025029
# 3             1.970854        0.070389           2.283922
# 4             3.397803        0.070389           3.549669
# ...                ...             ...                ...
# 1000          3.819668        0.238787           2.313246
# 1001          4.034744        1.967169           3.206331
# 1002          4.133399        1.786596           2.799087
# 1003          3.396434        0.400538           6.646451
# 1004          3.033863        0.000000           3.496974
#
# [1005 rows x 3 columns]

# %%
# checking some columns values

import pandas as pd

# Load the CSV file into a DataFrame
filtered_arranged_table = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/DeepDEP/filtered_arranged_table.csv")

# Select columns based on partial names
selected_columns = filtered_arranged_table.filter(like="AAK1")
selected_columns = selected_columns.join(filtered_arranged_table.filter(like="ABCA4"))
selected_columns = selected_columns.join(filtered_arranged_table.filter(like="ACER3"))

# Display the selected columns
selected_columns
# Out:
#       AAK1 (22848) Exp  ABCA4 (24) Exp  ACER3 (55331) Exp
# 0             3.078951        2.443607           5.980025
# 1             2.292782        0.713696           3.648465
# 2             2.625270        0.163499           4.025029
# 3             1.970854        0.070389           2.283922
# 4             3.397803        0.070389           3.549669
# ...                ...             ...                ...
# 1000          3.819668        0.238787           2.313246
# 1001          4.034744        1.967169           3.206331
# 1002          4.133399        1.786596           2.799087
# 1003          3.396434        0.400538           6.646451
# 1004          3.033863        0.000000           3.496974
#
# [1005 rows x 3 columns]

# %%
# From correlation_table_diavalues_gt_0.csv which extract the diagonal values bigger than 0.1 and then file filtered_arranged_table.csv mach gene EXP with it to produce a dataset for ML.

import pandas as pd

# Read the first file and extract the row names as a list
first_file = '/content/drive/MyDrive/Colab Notebooks/correlation_table_diavalues_gt_0.csv'
df_first = pd.read_csv(first_file)
row_names = list(df_first.iloc[:, 0])

# Read the second file and select columns with matching names
second_file = '/content/drive/MyDrive/Colab Notebooks/DeepDEP/filtered_arranged_table.csv'
df_second = pd.read_csv(second_file)

# Filter columns from the second file based on matching row names
# columns_to_keep = ['DepMap_ID'] + [col for col in df_second.columns if col in row_names]
columns_to_keep = ['DepMap_ID'] + [col for col in df_second.columns if col in row_names]+['EIF2AK3 (9451) Dep','MYC (4609) Dep','NQO1 (1728) Dep','SF3B1 (23451) Dep','SQSTM1 (8878) Dep']
df_filtered = df_second[columns_to_keep]

# Save the modified second file
output_file = '/content/drive/MyDrive/Colab Notebooks/DeepDEP/filtered_arranged_table_modified.csv'
df_filtered.to_csv(output_file, index=False)

df_filtered
# Out:
#        DepMap_ID  AAK1 (22848) Exp  ABCA4 (24) Exp  ABCB6 (10058) Exp  \
# 0     ACH-000001          3.078951        2.443607           4.811985
# 1     ACH-000004          2.292782        0.713696           4.973152
# 2     ACH-000005          2.625270        0.163499           5.231509
# 3     ACH-000007          1.970854        0.070389           3.392317
# 4     ACH-000009          3.397803        0.070389           5.590662
# ...          ...               ...             ...                ...
# 1000  ACH-002785          3.819668        0.238787           3.730096
# 1001  ACH-002800          4.034744        1.967169           2.805292
# 1002  ACH-002834          4.133399        1.786596           3.226509
# 1003  ACH-002847          3.396434        0.400538           3.379898
# 1004  ACH-002926          3.033863        0.000000           4.672991
#
#       ABCD3 (5825) Exp  ABI2 (10152) Exp  ABLIM2 (84448) Exp  \
# 0             4.746313          5.388534            1.510962
# ...

# %%
# From correlation_table_A1BG_gt_01.csv which extract the ALL values bigger than 0.1 and then file filtered_arranged_table.csv mach gene EXP with it to produce a dataset for ML.

import pandas as pd

# Read the first file and extract the row names as a list
first_file = '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/correlation_table_A1BG_gt_01.csv'
df_first = pd.read_csv(first_file)
row_names = list(df_first.iloc[:, 0])

# Read the second file and select columns with matching names
second_file = '/content/drive/MyDrive/Colab Notebooks/DeepDEP/filtered_arranged_table.csv'
df_second = pd.read_csv(second_file)

# Filter columns from the second file based on matching row names
# columns_to_keep = ['DepMap_ID'] + [col for col in df_second.columns if col in row_names]
columns_to_keep = ['DepMap_ID'] + [col for col in df_second.columns if col in row_names]+['EIF2AK3 (9451) Dep','MYC (4609) Dep','NQO1 (1728) Dep','SF3B1 (23451) Dep','SQSTM1 (8878) Dep']
df_filtered = df_second[columns_to_keep]

# Save the modified second file
output_file = '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/A1BG_gt_01.csv'
df_filtered.to_csv(output_file, index=False)

df_filtered
# Out:
#        DepMap_ID  ABCA3 (21) Exp  ADAMTS7 (11173) Exp  AKIP1 (56672) Exp  \
# 0     ACH-000001        1.646163             1.541019           5.518850
# 1     ACH-000004        1.350497             1.339137           4.385431
# 2     ACH-000005        1.933573             0.584963           4.482203
# 3     ACH-000007        0.400538             0.124328           5.092969
# 4     ACH-000009        3.419539             0.056584           5.040454
# ...          ...             ...                  ...                ...
# 1000  ACH-002785        2.017922             0.389567           4.307429
# 1001  ACH-002800        2.459432             1.981853           4.211791
# 1002  ACH-002834        0.042644             2.592158           4.595742
# 1003  ACH-002847        0.526069             2.049631           5.684538
# 1004  ACH-002926        0.111031             1.090853           4.645010
#
#       AP2A2 (161) Exp  ARL8A (127829) Exp  EIF2AK3 (9451) Dep  MYC (4609) Dep  \
# ...

# %%
# checking some columns values wheather they are matched

import pandas as pd

# Load the CSV file into a DataFrame
filtered_arranged_table = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/DeepDEP/filtered_arranged_table.csv")

# Select columns based on partial names
selected_columns = filtered_arranged_table.filter(like="ABCA7")
selected_columns = selected_columns.join(filtered_arranged_table.filter(like="ACSL5"))
selected_columns = selected_columns.join(filtered_arranged_table.filter(like="AKIP1"))
selected_columns = selected_columns.join(filtered_arranged_table.filter(like="AP2A2"))
selected_columns = selected_columns.join(filtered_arranged_table.filter(like="ARL8A"))

# Display the selected columns
selected_columns
# Out:
#       ABCA7 (10347) Exp  ACSL5 (51703) Exp  AKIP1 (56672) Exp  \
# 0              2.121015           0.226509           5.518850
# 1              4.883132           4.942984           4.385431
# 2              3.475085           5.008989           4.482203
# 3              3.898208           6.969012           5.092969
# 4              3.351911           4.430954           5.040454
# ...                 ...                ...                ...
# 1000           1.280956           2.277985           4.307429
# 1001           2.620586           1.201634           4.211791
# 1002           2.523562           1.599318           4.595742
# 1003           2.794936           1.769772           5.684538
# 1004           1.097611           5.550285           4.645010
#
#       AP2A2 (161) Exp  ARL8A (127829) Exp
# 0            4.445594            4.624101
# 1            3.992768            4.889960
# 2            4.223423            4.187451
# 3            4.556429            4.340562
# ...

# %%
## From 'EIF2AK3 (9451) Dep', 'MYC (4609) Dep', 'NQO1 (1728) Dep', 'SF3B1 (23451) Dep', 'SQSTM1 (8878) Dep_gt_01.csv which extract the all values bigger than 0.1 and then file filtered_arranged_table.csv mach gene EXP with it to produce a dataset for ML.

import pandas as pd

# Define the input file paths for the first files
first_file_paths = [
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/EIF2AK3_(9451)_Dep_gt_01.csv',
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/MYC_(4609)_Dep_gt_01.csv',
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/NQO1_(1728)_Dep_gt_01.csv',
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/SF3B1_(23451)_Dep_gt_01.csv',
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/SQSTM1_(8878)_Dep_gt_01.csv'
]

# Read the second file and select columns with matching names
second_file = '/content/drive/MyDrive/Colab Notebooks/DeepDEP/filtered_arranged_table.csv'
df_second = pd.read_csv(second_file)

# Iterate over the first files and generate corresponding output files
for file_path in first_file_paths:
    # Read the first file and extract the row names as a list
    df_first = pd.read_csv(file_path)
    row_names = list(df_first.iloc[:, 0])

    # Filter columns from the second file based on matching row names
    columns_to_keep = ['DepMap_ID'] + [col for col in df_second.columns if col in row_names]+['EIF2AK3 (9451) Dep','MYC (4609) Dep','NQO1 (1728) Dep','SF3B1 (23451) Dep','SQSTM1 (8878) Dep']
    df_filtered = df_second[columns_to_keep]

    # Extract the gene name from the first file path
    gene_name = file_path.split('/')[-1].split('_')[0]

    # Save the modified second file as the corresponding output file
    output_file = f'/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/{gene_name}_gt_01.csv'
    df_filtered.to_csv(output_file, index=False)

    print(f"Saved filtered DataFrame for {gene_name} to {output_file}")
# Out:
# Saved filtered DataFrame for EIF2AK3 to /content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/EIF2AK3_gt_01.csv
# Saved filtered DataFrame for MYC to /content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/MYC_gt_01.csv
# Saved filtered DataFrame for NQO1 to /content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/NQO1_gt_01.csv
# Saved filtered DataFrame for SF3B1 to /content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/SF3B1_gt_01.csv
# Saved filtered DataFrame for SQSTM1 to /content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/SQSTM1_gt_01.csv

# %%
## From 'EIF2AK3 (9451) Dep', 'MYC (4609) Dep', 'NQO1 (1728) Dep', 'SF3B1 (23451) Dep', 'SQSTM1 (8878) Dep_gt_01.csv which extract the all values bigger than 0.1 and then file filtered_arranged_table_Oral_Squamous.csv mach gene EXP with it to produce a dataset for ML.

import pandas as pd

# Define the input file paths for the first files
first_file_paths = [
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/EIF2AK3_(9451)_Dep_gt_01.csv',
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/MYC_(4609)_Dep_gt_01.csv',
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/NQO1_(1728)_Dep_gt_01.csv',
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/SF3B1_(23451)_Dep_gt_01.csv',
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/SQSTM1_(8878)_Dep_gt_01.csv'
]

# Read the second file and select columns with matching names
second_file = '/content/drive/MyDrive/Colab Notebooks/Oral_Squamous_Cell_Carcinoma/filtered_arranged_table_Oral_Squamous.csv'
df_second = pd.read_csv(second_file)

# Iterate over the first files and generate corresponding output files
for file_path in first_file_paths:
    # Read the first file and extract the row names as a list
    df_first = pd.read_csv(file_path)
    row_names = list(df_first.iloc[:, 0])

    # Filter columns from the second file based on matching row names
    columns_to_keep = ['DepMap_ID'] + [col for col in df_second.columns if col in row_names]+['EIF2AK3 (9451) Dep','MYC (4609) Dep','NQO1 (1728) Dep','SF3B1 (23451) Dep','SQSTM1 (8878) Dep']
    df_filtered = df_second[columns_to_keep]

    # Extract the gene name from the first file path
    gene_name = file_path.split('/')[-1].split('_')[0]

    # Save the modified second file as the corresponding output file
    output_file = f'/content/drive/MyDrive/Colab Notebooks/Oral_Squamous_Cell_Carcinoma/{gene_name}_Oral_Squamous_gt_01.csv'
    df_filtered.to_csv(output_file, index=False)

    print(f"Saved filtered DataFrame for {gene_name} to {output_file}")
# Out:
# Saved filtered DataFrame for EIF2AK3 to /content/drive/MyDrive/Colab Notebooks/Oral_Squamous_Cell_Carcinoma/EIF2AK3_Oral_Squamous_gt_01.csv
# Saved filtered DataFrame for MYC to /content/drive/MyDrive/Colab Notebooks/Oral_Squamous_Cell_Carcinoma/MYC_Oral_Squamous_gt_01.csv
# Saved filtered DataFrame for NQO1 to /content/drive/MyDrive/Colab Notebooks/Oral_Squamous_Cell_Carcinoma/NQO1_Oral_Squamous_gt_01.csv
# Saved filtered DataFrame for SF3B1 to /content/drive/MyDrive/Colab Notebooks/Oral_Squamous_Cell_Carcinoma/SF3B1_Oral_Squamous_gt_01.csv
# Saved filtered DataFrame for SQSTM1 to /content/drive/MyDrive/Colab Notebooks/Oral_Squamous_Cell_Carcinoma/SQSTM1_Oral_Squamous_gt_01.csv

# %%
# Checking datasets

import pandas as pd

EIF2AK3_Oral_Squamous_gt_01 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Oral_Squamous_Cell_Carcinoma/EIF2AK3_Oral_Squamous_gt_01.csv")

EIF2AK3_Oral_Squamous_gt_01
# Out:
#      DepMap_ID  ABCA12 (26154) Exp  ATG3 (64422) Exp  BCL2A1 (597) Exp  \
# 0   ACH-000181            4.316870          4.746850          0.333424
# 1   ACH-000188            0.097611          5.053980          0.475085
# 2   ACH-000228            3.404631          5.759156          0.799087
# 3   ACH-000238            1.589763          5.548128          0.214125
# 4   ACH-000472            0.941106          5.021480          0.042644
# 5   ACH-000503            1.803227          5.370513          0.321928
# 6   ACH-000518            1.778209          5.567424          1.182692
# 7   ACH-000546            0.863938          5.023699          0.056584
# 8   ACH-000548            0.941106          5.015248          3.555816
# 9   ACH-000606            1.310340          6.118526          0.978196
# 10  ACH-000619            1.526069          5.247168          0.124328
# 11  ACH-000630            0.028569          5.058749          0.000000
# ...

# %%
## From 'EIF2AK3 (9451) Dep', 'MYC (4609) Dep', 'NQO1 (1728) Dep', 'SF3B1 (23451) Dep', 'SQSTM1 (8878) Dep_gt_00.csv which extract the all values bigger than 0 and then file filtered_arranged_table.csv mach gene EXP with it to produce a dataset for ML.

import pandas as pd

# Define the input file paths for the first files
first_file_paths = [
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/EIF2AK3_(9451)_Dep_gt_00.csv',
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/MYC_(4609)_Dep_gt_00.csv',
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/NQO1_(1728)_Dep_gt_00.csv',
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/SF3B1_(23451)_Dep_gt_00.csv',
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/SQSTM1_(8878)_Dep_gt_00.csv'
]

# Read the second file and select columns with matching names
second_file = '/content/drive/MyDrive/Colab Notebooks/DeepDEP/filtered_arranged_table.csv'
df_second = pd.read_csv(second_file)

# Iterate over the first files and generate corresponding output files
for file_path in first_file_paths:
    # Read the first file and extract the row names as a list
    df_first = pd.read_csv(file_path)
    row_names = list(df_first.iloc[:, 0])

    # Filter columns from the second file based on matching row names
    columns_to_keep = ['DepMap_ID'] + [col for col in df_second.columns if col in row_names]+['EIF2AK3 (9451) Dep','MYC (4609) Dep','NQO1 (1728) Dep','SF3B1 (23451) Dep','SQSTM1 (8878) Dep']
    df_filtered = df_second[columns_to_keep]

    # Extract the gene name from the first file path
    gene_name = file_path.split('/')[-1].split('_')[0]

    # Save the modified second file as the corresponding output file
    output_file = f'/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/{gene_name}_gt_00.csv'
    df_filtered.to_csv(output_file, index=False)

    print(f"Saved filtered DataFrame for {gene_name} to {output_file}")
# Out:
# Saved filtered DataFrame for EIF2AK3 to /content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/EIF2AK3_gt_00.csv
# Saved filtered DataFrame for MYC to /content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/MYC_gt_00.csv
# Saved filtered DataFrame for NQO1 to /content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/NQO1_gt_00.csv
# Saved filtered DataFrame for SF3B1 to /content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/SF3B1_gt_00.csv
# Saved filtered DataFrame for SQSTM1 to /content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/SQSTM1_gt_00.csv

# %%
## From 'EIF2AK3 (9451) Dep', 'MYC (4609) Dep', 'NQO1 (1728) Dep', 'SF3B1 (23451) Dep', 'SQSTM1 (8878) Dep_gt_00.csv which extract the all values bigger than 0 and then file filtered_arranged_table_Oral_Squamous.csv mach gene EXP with it to produce a dataset for ML.

import pandas as pd

# Define the input file paths for the first files
first_file_paths = [
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/EIF2AK3_(9451)_Dep_gt_00.csv',
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/MYC_(4609)_Dep_gt_00.csv',
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/NQO1_(1728)_Dep_gt_00.csv',
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/SF3B1_(23451)_Dep_gt_00.csv',
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/SQSTM1_(8878)_Dep_gt_00.csv'
]

# Read the second file and select columns with matching names
second_file = '/content/drive/MyDrive/Colab Notebooks/Oral_Squamous_Cell_Carcinoma/filtered_arranged_table_Oral_Squamous.csv'
df_second = pd.read_csv(second_file)

# Iterate over the first files and generate corresponding output files
for file_path in first_file_paths:
    # Read the first file and extract the row names as a list
    df_first = pd.read_csv(file_path)
    row_names = list(df_first.iloc[:, 0])

    # Filter columns from the second file based on matching row names
    columns_to_keep = ['DepMap_ID'] + [col for col in df_second.columns if col in row_names]+['EIF2AK3 (9451) Dep','MYC (4609) Dep','NQO1 (1728) Dep','SF3B1 (23451) Dep','SQSTM1 (8878) Dep']
    df_filtered = df_second[columns_to_keep]

    # Extract the gene name from the first file path
    gene_name = file_path.split('/')[-1].split('_')[0]

    # Save the modified second file as the corresponding output file
    output_file = f'/content/drive/MyDrive/Colab Notebooks/Oral_Squamous_Cell_Carcinoma/{gene_name}_Oral_Squamous_gt_00.csv'
    df_filtered.to_csv(output_file, index=False)

    print(f"Saved filtered DataFrame for {gene_name} to {output_file}")
# Out:
# Saved filtered DataFrame for EIF2AK3 to /content/drive/MyDrive/Colab Notebooks/Oral_Squamous_Cell_Carcinoma/EIF2AK3_Oral_Squamous_gt_00.csv
# Saved filtered DataFrame for MYC to /content/drive/MyDrive/Colab Notebooks/Oral_Squamous_Cell_Carcinoma/MYC_Oral_Squamous_gt_00.csv
# Saved filtered DataFrame for NQO1 to /content/drive/MyDrive/Colab Notebooks/Oral_Squamous_Cell_Carcinoma/NQO1_Oral_Squamous_gt_00.csv
# Saved filtered DataFrame for SF3B1 to /content/drive/MyDrive/Colab Notebooks/Oral_Squamous_Cell_Carcinoma/SF3B1_Oral_Squamous_gt_00.csv
# Saved filtered DataFrame for SQSTM1 to /content/drive/MyDrive/Colab Notebooks/Oral_Squamous_Cell_Carcinoma/SQSTM1_Oral_Squamous_gt_00.csv

# %%
## From 'EIF2AK3 (9451) Dep', 'MYC (4609) Dep', 'NQO1 (1728) Dep', 'SF3B1 (23451) Dep', 'SQSTM1 (8878) Dep_ng_01.csv which extract the all values less than -0.1 and then file filtered_arranged_table.csv mach gene EXP with it to produce a dataset for ML.

import pandas as pd

# Define the input file paths for the first files
first_file_paths = [
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/EIF2AK3_(9451)_Dep_ng_01.csv',
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/MYC_(4609)_Dep_ng_01.csv',
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/NQO1_(1728)_Dep_ng_01.csv',
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/SF3B1_(23451)_Dep_ng_01.csv',
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/SQSTM1_(8878)_Dep_ng_01.csv'
]

# Read the second file and select columns with matching names
second_file = '/content/drive/MyDrive/Colab Notebooks/DeepDEP/filtered_arranged_table.csv'
df_second = pd.read_csv(second_file)

# Iterate over the first files and generate corresponding output files
for file_path in first_file_paths:
    # Read the first file and extract the row names as a list
    df_first = pd.read_csv(file_path)
    row_names = list(df_first.iloc[:, 0])

    # Filter columns from the second file based on matching row names
    columns_to_keep = ['DepMap_ID'] + [col for col in df_second.columns if col in row_names]+['EIF2AK3 (9451) Dep','MYC (4609) Dep','NQO1 (1728) Dep','SF3B1 (23451) Dep','SQSTM1 (8878) Dep']
    df_filtered = df_second[columns_to_keep]

    # Extract the gene name from the first file path
    gene_name = file_path.split('/')[-1].split('_')[0]

    # Save the modified second file as the corresponding output file
    output_file = f'/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/{gene_name}_ng_01.csv'
    df_filtered.to_csv(output_file, index=False)

    print(f"Saved filtered DataFrame for {gene_name} to {output_file}")
# Out:
# Saved filtered DataFrame for EIF2AK3 to /content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/EIF2AK3_ng_01.csv
# Saved filtered DataFrame for MYC to /content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/MYC_ng_01.csv
# Saved filtered DataFrame for NQO1 to /content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/NQO1_ng_01.csv
# Saved filtered DataFrame for SF3B1 to /content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/SF3B1_ng_01.csv
# Saved filtered DataFrame for SQSTM1 to /content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/SQSTM1_ng_01.csv

# %%
## From 'EIF2AK3 (9451) Dep', 'MYC (4609) Dep', 'NQO1 (1728) Dep', 'SF3B1 (23451) Dep', 'SQSTM1 (8878) Dep_ng_01.csv which extract the all values bigger than 0 and then file filtered_arranged_table_Oral_Squamous.csv mach gene EXP with it to produce a dataset for ML.

import pandas as pd

# Define the input file paths for the first files
first_file_paths = [
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/EIF2AK3_(9451)_Dep_ng_01.csv',
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/MYC_(4609)_Dep_ng_01.csv',
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/NQO1_(1728)_Dep_ng_01.csv',
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/SF3B1_(23451)_Dep_ng_01.csv',
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/SQSTM1_(8878)_Dep_ng_01.csv'
]

# Read the second file and select columns with matching names
second_file = '/content/drive/MyDrive/Colab Notebooks/Oral_Squamous_Cell_Carcinoma/filtered_arranged_table_Oral_Squamous.csv'
df_second = pd.read_csv(second_file)

# Iterate over the first files and generate corresponding output files
for file_path in first_file_paths:
    # Read the first file and extract the row names as a list
    df_first = pd.read_csv(file_path)
    row_names = list(df_first.iloc[:, 0])

    # Filter columns from the second file based on matching row names
    columns_to_keep = ['DepMap_ID'] + [col for col in df_second.columns if col in row_names]+['EIF2AK3 (9451) Dep','MYC (4609) Dep','NQO1 (1728) Dep','SF3B1 (23451) Dep','SQSTM1 (8878) Dep']
    df_filtered = df_second[columns_to_keep]

    # Extract the gene name from the first file path
    gene_name = file_path.split('/')[-1].split('_')[0]

    # Save the modified second file as the corresponding output file
    output_file = f'/content/drive/MyDrive/Colab Notebooks/Oral_Squamous_Cell_Carcinoma/{gene_name}_Oral_Squamous_ng_01.csv'
    df_filtered.to_csv(output_file, index=False)

    print(f"Saved filtered DataFrame for {gene_name} to {output_file}")
# Out:
# Saved filtered DataFrame for EIF2AK3 to /content/drive/MyDrive/Colab Notebooks/Oral_Squamous_Cell_Carcinoma/EIF2AK3_Oral_Squamous_ng_01.csv
# Saved filtered DataFrame for MYC to /content/drive/MyDrive/Colab Notebooks/Oral_Squamous_Cell_Carcinoma/MYC_Oral_Squamous_ng_01.csv
# Saved filtered DataFrame for NQO1 to /content/drive/MyDrive/Colab Notebooks/Oral_Squamous_Cell_Carcinoma/NQO1_Oral_Squamous_ng_01.csv
# Saved filtered DataFrame for SF3B1 to /content/drive/MyDrive/Colab Notebooks/Oral_Squamous_Cell_Carcinoma/SF3B1_Oral_Squamous_ng_01.csv
# Saved filtered DataFrame for SQSTM1 to /content/drive/MyDrive/Colab Notebooks/Oral_Squamous_Cell_Carcinoma/SQSTM1_Oral_Squamous_ng_01.csv

# %%
# Checking datasets

import pandas as pd

modified_table = pd.read_csv("//content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/MYC_gt_01.csv")
modified_table
# Out:
#        DepMap_ID  ABCA7 (10347) Exp  ABCB11 (8647) Exp  ABHD14B (84836) Exp  \
# 0     ACH-000001           2.121015           0.014355             4.179511
# 1     ACH-000004           4.883132           0.275007             6.203397
# 2     ACH-000005           3.475085           0.189034             5.788686
# 3     ACH-000007           3.898208           0.014355             6.371907
# 4     ACH-000009           3.351911           0.000000             5.212180
# ...          ...                ...                ...                  ...
# 1000  ACH-002785           1.280956           0.000000             4.470537
# 1001  ACH-002800           2.620586           0.014355             4.651339
# 1002  ACH-002834           2.523562           0.000000             4.570463
# 1003  ACH-002847           2.794936           0.000000             5.132577
# 1004  ACH-002926           1.097611           0.014355             5.285032
#
# ...

# %%
# From correlation_table_diavalues_gt_03.csv which extract the diagonal values bigger than 0.3 and then file filtered_arranged_table.csv mach gene EXP with it to produce a dataset for ML.

import pandas as pd

# Read the first file and extract the row names as a list
first_file = '/content/drive/MyDrive/Colab Notebooks/correlation_table_diavalues_gt_03.csv'
df_first = pd.read_csv(first_file)
row_names = list(df_first.iloc[:, 0])

# Read the second file and select columns with matching names
second_file = '/content/drive/MyDrive/Colab Notebooks/DeepDEP/filtered_arranged_table.csv'
df_second = pd.read_csv(second_file)

# Filter columns from the second file based on matching row names
# columns_to_keep = ['DepMap_ID'] + [col for col in df_second.columns if col in row_names]
columns_to_keep = ['DepMap_ID'] + [col for col in df_second.columns if col in row_names]+['EIF2AK3 (9451) Dep','MYC (4609) Dep','NQO1 (1728) Dep','SF3B1 (23451) Dep','SQSTM1 (8878) Dep']
df_filtered = df_second[columns_to_keep]

# Save the modified second file
output_file = '/content/drive/MyDrive/Colab Notebooks/DeepDEP/filtered_arranged_table_modified_03.csv'
df_filtered.to_csv(output_file, index=False)

df_filtered
# Out:
#        DepMap_ID  ARHGAP29 (9411) Exp  ARL4C (10123) Exp  BCAR1 (9564) Exp  \
# 0     ACH-000001             7.570994           3.923149          4.506526
# 1     ACH-000004             0.189034           0.084064          0.250962
# 2     ACH-000005             0.263034           0.097611          0.214125
# 3     ACH-000007             1.855990           4.037382          4.491212
# 4     ACH-000009             3.635754           5.088311          5.914565
# ...          ...                  ...                ...               ...
# 1000  ACH-002785             6.633286           3.422233          2.541019
# 1001  ACH-002800             5.783719           5.549977          3.618239
# 1002  ACH-002834             5.003152           6.382667          4.006298
# 1003  ACH-002847             3.976364           5.433961          4.526069
# 1004  ACH-002926             2.189034           4.617063          2.244887
#
# ...

# %%
# From correlation_table_diavalues_gt_03.csv which extract the diagonal values bigger than 0.4 and then file filtered_arranged_table.csv mach gene EXP with it to produce a dataset for ML.

import pandas as pd

# Read the first file and extract the row names as a list
first_file = '/content/drive/MyDrive/Colab Notebooks/correlation_table_diavalues_gt_04.csv'
df_first = pd.read_csv(first_file)
row_names = list(df_first.iloc[:, 0])

# Read the second file and select columns with matching names
second_file = '/content/drive/MyDrive/Colab Notebooks/DeepDEP/filtered_arranged_table.csv'
df_second = pd.read_csv(second_file)

# Filter columns from the second file based on matching row names
# columns_to_keep = ['DepMap_ID'] + [col for col in df_second.columns if col in row_names]
columns_to_keep = ['DepMap_ID'] + [col for col in df_second.columns if col in row_names]+['EIF2AK3 (9451) Dep','MYC (4609) Dep','NQO1 (1728) Dep','SF3B1 (23451) Dep','SQSTM1 (8878) Dep']
df_filtered = df_second[columns_to_keep]

# Save the modified second file
output_file = '/content/drive/MyDrive/Colab Notebooks/DeepDEP/filtered_arranged_table_modified_04.csv'
df_filtered.to_csv(output_file, index=False)

df_filtered
# Out:
#        DepMap_ID  ARHGAP29 (9411) Exp  BCAR3 (8412) Exp  CCND1 (595) Exp  \
# 0     ACH-000001             7.570994          3.407353         7.437877
# 1     ACH-000004             0.189034          0.475085         1.056584
# 2     ACH-000005             0.263034          0.344828         2.295723
# 3     ACH-000007             1.855990          2.327687         5.198494
# 4     ACH-000009             3.635754          2.204767         7.428611
# ...          ...                  ...               ...              ...
# 1000  ACH-002785             6.633286          5.982537         5.191010
# 1001  ACH-002800             5.783719          4.852998         6.467116
# 1002  ACH-002834             5.003152          5.301222         6.474760
# 1003  ACH-002847             3.976364          5.730368        10.967010
# 1004  ACH-002926             2.189034          1.327687         8.036174
#
#       CDK6 (1021) Exp  CFLAR (8837) Exp  EGFR (1956) Exp  FERMT2 (10979) Exp  \
# ...

# %%
# From correlation_table_diavalues_ls_01.csv which extract the diagonal values less than -0.1 and then file filtered_arranged_table.csv mach gene EXP with it to produce a dataset for ML.

import pandas as pd

# Read the first file and extract the row names as a list
first_file = '/content/drive/MyDrive/Colab Notebooks/correlation_table_diavalues_ls_01.csv'
df_first = pd.read_csv(first_file)
row_names = list(df_first.iloc[:, 0])

# Read the second file and select columns with matching names
second_file = '/content/drive/MyDrive/Colab Notebooks/DeepDEP/filtered_arranged_table.csv'
df_second = pd.read_csv(second_file)

# Filter columns from the second file based on matching row names
# columns_to_keep = ['DepMap_ID'] + [col for col in df_second.columns if col in row_names]
columns_to_keep = ['DepMap_ID'] + [col for col in df_second.columns if col in row_names]+['EIF2AK3 (9451) Dep','MYC (4609) Dep','NQO1 (1728) Dep','SF3B1 (23451) Dep','SQSTM1 (8878) Dep']
df_filtered = df_second[columns_to_keep]

# Save the modified second file
output_file = '/content/drive/MyDrive/Colab Notebooks/DeepDEP/filtered_arranged_table_modified_neg01.csv'
df_filtered.to_csv(output_file, index=False)

df_filtered
# Out:
#        DepMap_ID  ABCB7 (22) Exp  ABCC3 (8714) Exp  ABCE1 (6059) Exp  \
# 0     ACH-000001        4.771886          3.301588          6.037163
# 1     ACH-000004        4.238023          2.182692          5.823495
# 2     ACH-000005        4.621173          1.304511          6.767125
# 3     ACH-000007        3.582556          6.802064          5.558880
# 4     ACH-000009        4.415488          4.032101          6.666331
# ...          ...             ...               ...               ...
# 1000  ACH-002785        4.857981          4.734981          6.394034
# 1001  ACH-002800        4.744699          1.910733          5.635464
# 1002  ACH-002834        4.505256          3.184280          7.266880
# 1003  ACH-002847        4.067811          5.246788          5.988230
# 1004  ACH-002926        4.609400          0.000000          6.083001
#
#       ABCF1 (23) Exp  ACD (65057) Exp  ADAMTS4 (9507) Exp  ADGRG1 (9289) Exp  \
# ...

# %%
# From correlation_table_diavalues_ls_01.csv which extract the diagonal values less than -0.2 and then file filtered_arranged_table.csv mach gene EXP with it to produce a dataset for ML.

import pandas as pd

# Read the first file and extract the row names as a list
first_file = '/content/drive/MyDrive/Colab Notebooks/correlation_table_diavalues_ls_02.csv'
df_first = pd.read_csv(first_file)
row_names = list(df_first.iloc[:, 0])

# Read the second file and select columns with matching names
second_file = '/content/drive/MyDrive/Colab Notebooks/DeepDEP/filtered_arranged_table.csv'
df_second = pd.read_csv(second_file)

# Filter columns from the second file based on matching row names
# columns_to_keep = ['DepMap_ID'] + [col for col in df_second.columns if col in row_names]
columns_to_keep = ['DepMap_ID'] + [col for col in df_second.columns if col in row_names]+['EIF2AK3 (9451) Dep','MYC (4609) Dep','NQO1 (1728) Dep','SF3B1 (23451) Dep','SQSTM1 (8878) Dep']
df_filtered = df_second[columns_to_keep]

# Save the modified second file
output_file = '/content/drive/MyDrive/Colab Notebooks/DeepDEP/filtered_arranged_table_modified_neg02.csv'
df_filtered.to_csv(output_file, index=False)

df_filtered
# Out:
#        DepMap_ID  AFAP1 (60312) Exp  AMOTL2 (51421) Exp  ARL14 (80117) Exp  \
# 0     ACH-000001           5.688180            8.685975           0.731183
# 1     ACH-000004           0.422233            0.464668           0.028569
# 2     ACH-000005           0.941106            1.007196           0.000000
# 3     ACH-000007           2.809414            3.716991           3.171527
# 4     ACH-000009           3.662205            6.704734           1.827819
# ...          ...                ...                 ...                ...
# 1000  ACH-002785           5.814807            5.322649           0.124328
# 1001  ACH-002800           4.435629            4.333424           2.042644
# 1002  ACH-002834           4.187451            5.453847           1.613532
# 1003  ACH-002847           4.386121            5.783980           0.443607
# 1004  ACH-002926           2.107688            3.051372           0.000000
#
#       ASH2L (9070) Exp  ATP6AP1 (537) Exp  ATP6AP2 (10159) Exp  \
# ...

# %%
# Create a list of column names to preserve
preserved_columns = ["EIF2AK3", "SF3B1", "NQO1", "SQSTM1", "MYC", "HSP70"]

# Filter the columns based on the preserved column names
filtered_columns = [col for col in arranged_table_reordered.columns if ((col.endswith(" Dep") or col.endswith(" Exp")) and col.split(" ")[0] in preserved_columns) or (not col.endswith(" Dep") and not col.endswith(" Exp"))]

# Create a new DataFrame with the filtered columns
filtered_arranged_table_02 = arranged_table_reordered[filtered_columns]

# Save the filtered_arranged_table_02 DataFrame to a CSV file
filtered_arranged_table_02.to_csv("/content/drive/MyDrive/Colab Notebooks/DeepDEP/filtered_arranged_table_02.csv", index=False)

filtered_arranged_table_02
# Out:
#        DepMap_ID  EIF2AK3 (9451) Exp  MYC (4609) Exp  NQO1 (1728) Exp  \
# 0     ACH-000001            4.766595        4.820690         7.322018
# 1     ACH-000004            3.411426        8.787446         2.448901
# 2     ACH-000005            3.925050        9.105620         3.713696
# 3     ACH-000007            2.990955        7.170125         7.876578
# 4     ACH-000009            4.701549        6.685800         7.612574
# ...          ...                 ...             ...              ...
# 1000  ACH-002785            4.555816        5.855990         6.590961
# 1001  ACH-002800            4.392317        4.324811         6.670302
# 1002  ACH-002834            4.286881        4.420213         4.854993
# 1003  ACH-002847            3.543496        4.729009         9.859938
# 1004  ACH-002926            3.709291        5.609991         8.146238
#
#       SF3B1 (23451) Exp  SQSTM1 (8878) Exp  EIF2AK3 (9451) Dep  \
# ...

# %%
# Check if there are any missing values

import pandas as pd

# Read the CSV file
filtered_arranged_table = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/DeepDEP/filtered_arranged_table.csv")

if filtered_arranged_table.isna().values.any():
    print("The DataFrame has missing values.")
else:
    print("The DataFrame does not have any missing values.")
# Out:
# The DataFrame does not have any missing values.

# %%
# Check if there are any missing values

import pandas as pd

# Read the CSV file
filtered_arranged_table_02 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/DeepDEP/filtered_arranged_table_02.csv")

if filtered_arranged_table_02.isna().values.any():
    print("The DataFrame has missing values.")
else:
    print("The DataFrame does not have any missing values.")
# Out:
# The DataFrame does not have any missing values.

# %%
# Check if there are any missing values

import pandas as pd

# Read the CSV file
filtered_arranged_table_modified = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/DeepDEP/filtered_arranged_table_modified.csv")

if filtered_arranged_table_modified.isna().values.any():
    print("The DataFrame has missing values.")
else:
    print("The DataFrame does not have any missing values.")
# Out:
# The DataFrame does not have any missing values.

# %%
# Find the column names exactly matching the specified strings
target_columns = filtered_arranged_table.columns[filtered_arranged_table.columns.str.match('EIF2AK3 |SF3B1 |NQO1 |SQSTM1 |MYC |HSP70 ')]

target_columns
# Out:
# Index(['EIF2AK3 (9451) Exp', 'MYC (4609) Exp', 'NQO1 (1728) Exp',
#        'SF3B1 (23451) Exp', 'SQSTM1 (8878) Exp', 'EIF2AK3 (9451) Dep',
#        'MYC (4609) Dep', 'NQO1 (1728) Dep', 'SF3B1 (23451) Dep',
#        'SQSTM1 (8878) Dep'],
#       dtype='object')

# %%
column_index = filtered_arranged_table.columns.get_loc(filtered_arranged_table.columns[filtered_arranged_table.columns.str.contains("EIF2AK3")][0])
print(column_index)
# Out:
# 4481

# %%
column_indices = [i for i, col in enumerate(filtered_arranged_table.columns) if "EIF2AK3" in col]
print(column_indices)
# Out:
# [4481, 17284]

# %%
import pandas as pd

# Read the CSV file and assign it to filtered_arranged_table
filtered_arranged_table = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/DeepDEP/filtered_arranged_table.csv")

# Subset of first 10 rows and first 10 columns
subset = filtered_arranged_table.iloc[:11, :11]

# Columns '17284' and '17285'
extra_columns = filtered_arranged_table.iloc[:11, [17284, 17285]]

# Concatenate the subsets horizontally into ML_test_table
ML_test_table = pd.concat([subset, extra_columns], axis=1)

# Save the ML_test_table DataFrame to a CSV file
ML_test_table.to_csv("/content/drive/MyDrive/Colab Notebooks/DeepDEP/ML_test_table.csv", index=False)

ML_test_table
# Out:
#      DepMap_ID  A1BG (1) Exp  A1CF (29974) Exp  A2M (2) Exp  \
# 0   ACH-000001      3.116032          0.056584     0.226509
# 1   ACH-000004      4.178715          0.000000     0.214125
# 2   ACH-000005      4.003602          0.014355     0.137504
# 3   ACH-000007      0.137504          1.405992     0.201634
# 4   ACH-000009      1.464668          3.586164     0.250962
# 5   ACH-000011      1.035624          0.084064     0.042644
# 6   ACH-000012      2.341986          0.028569     0.070389
# 7   ACH-000013      2.662205          0.028569     0.084064
# 8   ACH-000014      6.058749          0.042644     6.260402
# 9   ACH-000015      4.808385          0.214125     3.297191
# 10  ACH-000017      3.378512          0.014355     0.163499
#
#     A2ML1 (144568) Exp  A3GALT2 (127550) Exp  A4GALT (53947) Exp  \
# 0             0.111031              0.000000            1.035624
# 1             0.344828              0.070389            0.097611
# ...
